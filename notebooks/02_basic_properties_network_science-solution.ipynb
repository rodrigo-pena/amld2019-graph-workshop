# %% [markdown]
# # 2. Basic properties: Network Science

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import utils

# %%
routes, airports, pos, G = utils.preprocess_flight_routes()

# %%
utils.display_map(G, pos)

# %% [markdown]
# ## 2.1. Degree distribution

# %% [markdown]
# ## 2.2. Diameter

# %% [markdown]
# ## 2.3. Sparsity

# %% [markdown]
# ## 2.4. Connectedness

# %%
largest_cc = max(nx.connected_component_subgraphs(G), key=len)

# %% [markdown]
# ## 2.5. Shortest paths

# %% [markdown]
# ## 2.6. Modularity

# %% [markdown]
# ## 2.7. Centrality
